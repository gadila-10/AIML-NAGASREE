# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("data_clean.csv")
data
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
data1=data.drop(['Unnamed: 0','Temp C'],axis=1)
data1
# Out:
#      Ozone  Solar.R  Wind Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4     5    1  2010    67       S
# 1     36.0    118.0   8.0     5    2  2010    72       C
# 2     12.0    149.0  12.6     5    3  2010    74      PS
# 3     18.0    313.0  11.5     5    4  2010    62       S
# 4      NaN      NaN  14.3     5    5  2010    56       S
# ..     ...      ...   ...   ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4     5    1  2010    67       C
# 154   30.0    193.0   6.9     9   26  2010    70      PS
# 155    NaN    145.0  13.2     9   27  2010    77       S
# 156   14.0    191.0  14.3     9   28  2010    75       S
# 157   18.0    131.0   8.0     9   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    158 non-null    object
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %%
#convert  the month to float to datatype
data1['Month']=pd.to_numeric(data['Month'],errors='coerce')
data1
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 0     41.0    190.0   7.4    5.0    1  2010    67       S
# 1     36.0    118.0   8.0    5.0    2  2010    72       C
# 2     12.0    149.0  12.6    5.0    3  2010    74      PS
# 3     18.0    313.0  11.5    5.0    4  2010    62       S
# 4      NaN      NaN  14.3    5.0    5  2010    56       S
# ..     ...      ...   ...    ...  ...   ...   ...     ...
# 153   41.0    190.0   7.4    5.0    1  2010    67       C
# 154   30.0    193.0   6.9    9.0   26  2010    70      PS
# 155    NaN    145.0  13.2    9.0   27  2010    77       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S
# 157   18.0    131.0   8.0    9.0   29  2010    76       C
#
# [158 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Ozone    120 non-null    float64
#  1   Solar.R  151 non-null    float64
#  2   Wind     158 non-null    float64
#  3   Month    157 non-null    float64
#  4   Day      158 non-null    int64
#  5   Year     158 non-null    int64
#  6   Temp     158 non-null    int64
#  7   Weather  155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
#checking for duplicate rows one only 
data1[data1.duplicated()]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1[data1.duplicated(keep=False)]
# Out:
#      Ozone  Solar.R  Wind  Month  Day  Year  Temp Weather
# 150   14.0    191.0  14.3    9.0   28  2010    75       S
# 156   14.0    191.0  14.3    9.0   28  2010    75       S

# %%
data1.rename({'Solar.R':'Solar','Temp':'Temperature'},axis=1,inplace=True)
data1
# Out:
#      Ozone  Solar  Wind  Month  Day  Year  Temperature Weather
# 0     41.0  190.0   7.4    5.0    1  2010           67       S
# 1     36.0  118.0   8.0    5.0    2  2010           72       C
# 2     12.0  149.0  12.6    5.0    3  2010           74      PS
# 3     18.0  313.0  11.5    5.0    4  2010           62       S
# 4      NaN    NaN  14.3    5.0    5  2010           56       S
# ..     ...    ...   ...    ...  ...   ...          ...     ...
# 153   41.0  190.0   7.4    5.0    1  2010           67       C
# 154   30.0  193.0   6.9    9.0   26  2010           70      PS
# 155    NaN  145.0  13.2    9.0   27  2010           77       S
# 156   14.0  191.0  14.3    9.0   28  2010           75       S
# 157   18.0  131.0   8.0    9.0   29  2010           76       C
#
# [158 rows x 8 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ozone        120 non-null    float64
#  1   Solar        151 non-null    float64
#  2   Wind         158 non-null    float64
#  3   Month        157 non-null    float64
#  4   Day          158 non-null    int64
#  5   Year         158 non-null    int64
#  6   Temperature  158 non-null    int64
#  7   Weather      155 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data1.isnull().sum()
# Out:
# Ozone          38
# Solar           7
# Wind            0
# Month           1
# Day             0
# Year            0
# Temperature     0
# Weather         3
# dtype: int64

# %%
#visualize
cols=data1.columns
colours=['black','yellow']
sns.heatmap(data1[cols].isnull(),cmap=sns.color_palette(colours),cbar=True)
# Out:
# <Axes: >

# %%
#median and mean
median=data1['Ozone'].median()
mean=data1['Ozone'].mean()
print("MEDIAN",median)
print("mean",mean)
# Out:
# MEDIAN 30.5
# mean 41.583333333333336

# %%
#replace the qzone missing values with median value
data1['Ozone']=data1['Ozone'].fillna(median)
data1.isnull().sum()
# Out:
# Ozone          0
# Solar          7
# Wind           0
# Month          1
# Day            0
# Year           0
# Temperature    0
# Weather        3
# dtype: int64

# %%
data1['Solar']=data1['Solar'].fillna(median)
data1.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          1
# Day            0
# Year           0
# Temperature    0
# Weather        3
# dtype: int64

# %%
print(data1['Weather'].value_counts())
m_weather=data1['Weather'].mode()[0]
print(m_weather)
# Out:
# Weather
# S     59
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
data1['Weather']=data1['Weather'].fillna(m_weather)
data1.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          1
# Day            0
# Year           0
# Temperature    0
# Weather        0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ozone        158 non-null    float64
#  1   Solar        158 non-null    float64
#  2   Wind         158 non-null    float64
#  3   Month        157 non-null    float64
#  4   Day          158 non-null    int64
#  5   Year         158 non-null    int64
#  6   Temperature  158 non-null    int64
#  7   Weather      158 non-null    object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 10.0+ KB

# %%
data1['Month']=data1['Month'].fillna(m_weather)
data1.isnull().sum()
# Out:
# Ozone          0
# Solar          0
# Wind           0
# Month          0
# Day            0
# Year           0
# Temperature    0
# Weather        0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ozone        158 non-null    float64
#  1   Solar        158 non-null    float64
#  2   Wind         158 non-null    float64
#  3   Month        158 non-null    object
#  4   Day          158 non-null    int64
#  5   Year         158 non-null    int64
#  6   Temperature  158 non-null    int64
#  7   Weather      158 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %%
print(data1['Month'].value_counts())
m_weather=data1['Month'].mode()[0]
print(m_weather)
# Out:
# Month
# 9.0    34
# 5.0    31
# 7.0    31
# 8.0    31
# 6.0    30
# S       1
# Name: count, dtype: int64
# 9.0

# %%
data1.tail()
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temperature Weather
# 153   41.0  190.0   7.4   5.0    1  2010           67       C
# 154   30.0  193.0   6.9   9.0   26  2010           70      PS
# 155   30.5  145.0  13.2   9.0   27  2010           77       S
# 156   14.0  191.0  14.3   9.0   28  2010           75       S
# 157   18.0  131.0   8.0   9.0   29  2010           76       C

# %%
data1[data1.duplicated()]
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temperature Weather
# 156   14.0  191.0  14.3   9.0   28  2010           75       S

# %%
data1.reset_index(drop=True)
# Out:
#      Ozone  Solar  Wind Month  Day  Year  Temperature Weather
# 0     41.0  190.0   7.4   5.0    1  2010           67       S
# 1     36.0  118.0   8.0   5.0    2  2010           72       C
# 2     12.0  149.0  12.6   5.0    3  2010           74      PS
# 3     18.0  313.0  11.5   5.0    4  2010           62       S
# 4     30.5   30.5  14.3   5.0    5  2010           56       S
# ..     ...    ...   ...   ...  ...   ...          ...     ...
# 153   41.0  190.0   7.4   5.0    1  2010           67       C
# 154   30.0  193.0   6.9   9.0   26  2010           70      PS
# 155   30.5  145.0  13.2   9.0   27  2010           77       S
# 156   14.0  191.0  14.3   9.0   28  2010           75       S
# 157   18.0  131.0   8.0   9.0   29  2010           76       C
#
# [158 rows x 8 columns]

# %% [markdown]
# ### detection of outliers in the columns

# %% [markdown]
# ### m1:using histograms and box plots

# %%
#create a figure with two subplot,stacked vertical
fig,axes=plt.subplots(2,1,figsize=(8,6),gridspec_kw={'height_ratios':[1,3]})
#plot the boxplot in the first top)subplot)
sns.boxplot(data=data1['Ozone'],ax=axes[0],color='skyblue',width=0.5,orient='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
#plot the histograms with kde curve in the second bottom subplot
sns.histplot(data1["Ozone"],kde=True,ax=axes[1],color='purple',bins=30)
axes[1].set_title("Histogram with kde")
axes[1].set_xlabel("Ozone levels")
axes[1].set_ylabel("Frequency")
#Adjust layout 
plt.tight_layout()
#show the plot
plt.show()

# %% [markdown]
# ## Observations
# - the ozone column has extreme values beyond 81 as seen from box plot
# - the same is confirmed from the below right-skewed histogram

# %%
#create a figure with two subplot,stacked vertical
fig,axes=plt.subplots(2,1,figsize=(8,6),gridspec_kw={'height_ratios':[1,3]})
#plot the boxplot in the first top)subplot)
sns.boxplot(data=data1['Solar'],ax=axes[0],color='skyblue',width=0.5,orient='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
#plot the histograms with kde curve in the second bottom subplot
sns.histplot(data1["Solar"],kde=True,ax=axes[1],color='purple',bins=30)
axes[1].set_title("Histogram with kde")
axes[1].set_xlabel("Ozone levels")
axes[1].set_ylabel("Frequency")
#Adjust layout 
plt.tight_layout()
#show the plot
plt.show()

# %% [markdown]
# ### Obsevations
# - there is no outlier for solar
# - It is a not a perfect distribution but slightly left-skewed histogram

# %%
sns.violinplot(data=data1["Ozone"],color='lightgreen')
plt.title("ViolinPlot")
# Out:
# Text(0.5, 1.0, 'ViolinPlot')

# %%
sns.violinplot(data=data1["Solar"],color='lightgreen')
plt.title("ViolinPlot")
# Out:
# Text(0.5, 1.0, 'ViolinPlot')

# %%
#Display boxplot for ozone
plt.figure(figsize=(6,2))
plt.boxplot(data1["Ozone"],vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2afebf666c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2afef695460>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2afef694f20>],
#  'medians': [<matplotlib.lines.Line2D at 0x2afef695970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2afef695b80>],
#  'means': []}

# %%
#extract outliers from boxplot for Ozone column
plt.figure(figsize=(6,2))
boxplot_data=plt.boxplot(data1["Ozone"],vert=False)
[item.get_xdata() for item in boxplot_data['fliers']]
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %% [markdown]
# ### method 2 for outlier detection
# - using mu +/-3*sigma limits(sdm)

# %%
data1["Ozone"].describe()
# Out:
# count    158.000000
# mean      38.917722
# std       28.794730
# min        1.000000
# 25%       21.000000
# 50%       30.500000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu=data1["Ozone"].describe()[1]
sigma=data1["Ozone"].describe()[2]
for x in data1["Ozone"]:
    if((x<(mu-3*sigma)) or (x>(mu+3*sigma))):
        print(x)
# Out:
# 135.0
# 168.0
# C:\Users\SIRI\AppData\Local\Temp\ipykernel_14008\2479272794.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu=data1["Ozone"].describe()[1]
# C:\Users\SIRI\AppData\Local\Temp\ipykernel_14008\2479272794.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma=data1["Ozone"].describe()[2]

# %% [markdown]
# # Observations
# - It is observed that only two outliers are idenfied using std method
# - In box plot method more no of outliers are identified
# - This is because the assumption of normality is not satified in this column

# %%
import scipy.stats as st
plt.figure(figsize=(8,6))
st.probplot(data1["Ozone"],dist="norm",plot=plt)
plt.title("Q-Q plot for Outlier Detection",fontsize=14)
plt.xlabel("Theoretical Quantiles",fontsize=12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %% [markdown]
# ## Observations from Q-Q plot
#  - The data does not follow distribution as the data points are deviating significantly away from red line
# - The data shows a right skewed distribution and possible outliers

# %%
import scipy.stats as st
plt.figure(figsize=(8,6))
st.probplot(data1["Solar"],dist="norm",plot=plt)
plt.title("Q-Q plot for Outlier Detection",fontsize=14)
plt.xlabel("Theoretical Quantiles",fontsize=12)
# Out:
# Text(0.5, 0, 'Theoretical Quantiles')

# %%
sns.swarmplot(data=data1,x="Weather",y="Ozone",color="orange",palette="Set2",size=6)
# Out:
# C:\Users\SIRI\AppData\Local\Temp\ipykernel_14008\1590678044.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data1,x="Weather",y="Ozone",color="orange",palette="Set2",size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.violinplot(data=data1["Ozone"],color="green")
plt.title("violinplot")
plt.show()

# %%
sns.stripplot(data=data1,x="Weather",y="Ozone",color="orange",palette="Set1",size=6,jitter=True)
# Out:
# C:\Users\SIRI\AppData\Local\Temp\ipykernel_14008\1600510537.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=data1,x="Weather",y="Ozone",color="orange",palette="Set1",size=6,jitter=True)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.kdeplot(data=data1["Ozone"],fill=True,color="blue")
sns.rugplot(data=data1["Ozone"],color="black")
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
#category wise boxplot for ozone
sns.boxplot(data=data1,x="Weather",y="Ozone")
# Out:
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %% [markdown]
# ## Correlation coefficient and pair plots

# %%
plt.scatter(data1["Wind"],data1["Temperature"])

# %%
#correlation blw wind and temp
data1["Wind"].corr(data1["Temperature"])
# Out:
# -0.441246717631239

# %% [markdown]
# ## observations
# - The correlation b/w wind and temp is observed to be negatively correlated with mild strength

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Ozone        158 non-null    float64
#  1   Solar        158 non-null    float64
#  2   Wind         158 non-null    float64
#  3   Month        158 non-null    object
#  4   Day          158 non-null    int64
#  5   Year         158 non-null    int64
#  6   Temperature  158 non-null    int64
#  7   Weather      158 non-null    object
# dtypes: float64(3), int64(3), object(2)
# memory usage: 10.0+ KB

# %%
#read all numeric columns into new table data1_numeric
data1_numeric=data1.iloc[:,[0,1,2,6]]
data1_numeric
# Out:
#      Ozone  Solar  Wind  Temperature
# 0     41.0  190.0   7.4           67
# 1     36.0  118.0   8.0           72
# 2     12.0  149.0  12.6           74
# 3     18.0  313.0  11.5           62
# 4     30.5   30.5  14.3           56
# ..     ...    ...   ...          ...
# 153   41.0  190.0   7.4           67
# 154   30.0  193.0   6.9           70
# 155   30.5  145.0  13.2           77
# 156   14.0  191.0  14.3           75
# 157   18.0  131.0   8.0           76
#
# [158 rows x 4 columns]

# %%
#print correlation for all above columns
data1_numeric.corr()
# Out:
#                 Ozone     Solar      Wind  Temperature
# Ozone        1.000000  0.276848 -0.526616     0.596304
# Solar        0.276848  1.000000 -0.031312     0.282061
# Wind        -0.526616 -0.031312  1.000000    -0.441247
# Temperature  0.596304  0.282061 -0.441247     1.000000

# %% [markdown]
# ## Observations
# - The highest correlation strength is observed b/w Ozone and Temp(0.597087)
# -  The next highest correlation strength is observed b/w Ozone and wind(-0.523738)
# -  The next highest correlation strength is observed b/w wind and temp(-0.41228)
# - The least highest correlation strength is observed b/w solar and wind(-0.031312)

# %%
#plot a pair plot b/w all numeric columns using deaborn
sns.pairplot(data1_numeric)

# %%
data1.head()
# Out:
#    Ozone  Solar  Wind Month  Day  Year  Temperature Weather
# 0   41.0  190.0   7.4   5.0    1  2010           67       S
# 1   36.0  118.0   8.0   5.0    2  2010           72       C
# 2   12.0  149.0  12.6   5.0    3  2010           74      PS
# 3   18.0  313.0  11.5   5.0    4  2010           62       S
# 4   30.5   30.5  14.3   5.0    5  2010           56       S

# %%
data2=pd.get_dummies(data1,columns=['Weather','Month'])
data2
# Out:
#      Ozone  Solar  Wind  Day  Year  Temperature  Weather_C  Weather_PS  \
# 0     41.0  190.0   7.4    1  2010           67      False       False
# 1     36.0  118.0   8.0    2  2010           72       True       False
# 2     12.0  149.0  12.6    3  2010           74      False        True
# 3     18.0  313.0  11.5    4  2010           62      False       False
# 4     30.5   30.5  14.3    5  2010           56      False       False
# ..     ...    ...   ...  ...   ...          ...        ...         ...
# 153   41.0  190.0   7.4    1  2010           67       True       False
# 154   30.0  193.0   6.9   26  2010           70      False        True
# 155   30.5  145.0  13.2   27  2010           77      False       False
# 156   14.0  191.0  14.3   28  2010           75      False       False
# 157   18.0  131.0   8.0   29  2010           76       True       False
#
#      Weather_S  Month_5.0  Month_6.0  Month_7.0  Month_8.0  Month_9.0  Month_S
# ...

# %% [markdown]
# # Normalization

# %%
data1_numeric.values
# Out:
# array([[ 41. , 190. ,   7.4,  67. ],
#        [ 36. , 118. ,   8. ,  72. ],
#        [ 12. , 149. ,  12.6,  74. ],
#        [ 18. , 313. ,  11.5,  62. ],
#        [ 30.5,  30.5,  14.3,  56. ],
#        [ 28. ,  30.5,  14.9,  66. ],
#        [ 23. , 299. ,   8.6,  65. ],
#        [ 19. ,  99. ,  13.8,  59. ],
#        [  8. ,  19. ,  20.1,  61. ],
#        [ 30.5, 194. ,   8.6,  69. ],
#        [  7. ,  30.5,   6.9,  74. ],
#        [ 16. , 256. ,   9.7,  69. ],
#        [ 11. , 290. ,   9.2,  66. ],
#        [ 14. , 274. ,  10.9,  68. ],
#        [ 18. ,  65. ,  13.2,  58. ],
#        [ 14. , 334. ,  11.5,  64. ],
#        [ 34. , 307. ,  12. ,  66. ],
#        [  6. ,  78. ,  18.4,  57. ],
#        [ 30. , 322. ,  11.5,  68. ],
#        [ 11. ,  44. ,   9.7,  62. ],
#        [  1. ,   8. ,   9.7,  59. ],
#        [ 11. , 320. ,  16.6,  73. ],
#        [  4. ,  25. ,   9.7,  61. ],
#        [ 32. ,  92. ,  12. ,  61. ],
#        [ 30.5,  66. ,  16.6,  57. ],
# ...

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler
arr=data1_numeric.values
scaler=MinMaxScaler(feature_rage=(0,1))
rescaledx=scaler.fit_transform(arr)
#transformed data
set_printoptions(precision=2)
print(rescaledx[0:10,:])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 4
#       2 from sklearn.preprocessing import MinMaxScaler
#       3 arr=data1_numeric.values
# ----> 4 scaler=MinMaxScaler(feature_rage=(0,1))
#       5 rescaledx=scaler.fit_transform(arr)
#       6 #transformed data
#
# TypeError: MinMaxScaler.__init__() got an unexpected keyword argument 'feature_rage'
