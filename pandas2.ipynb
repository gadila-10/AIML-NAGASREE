# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#    sepal.length  sepal.width  petal.length  petal.width     variety
# 0           5.1          3.5           1.4          0.2      setosa
# 1           4.9          3.0           1.4          0.2  versicolor
# 2           4.7          3.2           1.3          0.2      setosa
# 3           4.6          3.1           1.5          0.2   virgincia
# 4           5.0          3.6           1.4          0.2      setosa
# 5           5.4          3.9           1.7          0.4  versicolor
# 6           4.6          3.4           1.4          0.3   virgincia

# %%
#select values conditionally
df[df["variety"]=="setosa"]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df[df["sepal.width"]<3.5]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width     variety
# 1           4.9          3.0           1.4          0.2  versicolor
# 2           4.7          3.2           1.3          0.2      setosa
# 3           4.6          3.1           1.5          0.2   virgincia
# 6           4.6          3.4           1.4          0.3   virgincia

# %%
# sort the rows in ascending/decending
df.sort_values(by="sepal.length")
# Out:
#    sepal.length  sepal.width  petal.length  petal.width     variety
# 3           4.6          3.1           1.5          0.2   virgincia
# 6           4.6          3.4           1.4          0.3   virgincia
# 2           4.7          3.2           1.3          0.2      setosa
# 1           4.9          3.0           1.4          0.2  versicolor
# 4           5.0          3.6           1.4          0.2      setosa
# 0           5.1          3.5           1.4          0.2      setosa
# 5           5.4          3.9           1.7          0.4  versicolor

# %%
#use of graphy() method
df[["sepal.length"]].groupby(df["variety"]).mean()
# Out:
#             sepal.length
# variety
# setosa          4.933333
# versicolor      5.150000
# virgincia       4.600000

# %%
df[["sepal.length","petal.width"]].groupby(df["variety"]).mean()
# Out:
#             sepal.length  petal.width
# variety
# setosa          4.933333         0.20
# versicolor      5.150000         0.30
# virgincia       4.600000         0.25

# %% [markdown]
# reshape the data

# %%
import pandas as pd
data={
    'user id':[1,1,2,2,3,3,4,3,7],
    'movie':['inception','titantic','inception','avatar','titantic','avatar','lion king','inter stellar','bahubali'],
    'rating':[9,8,7,10,9,8,7,8,9]
}
df=pd.DataFrame(data)
print(df)
#pivot the table
pivot
# Out:
#    user id          movie  rating
# 0        1      inception       9
# 1        1       titantic       8
# 2        2      inception       7
# 3        2         avatar      10
# 4        3       titantic       9
# 5        3         avatar       8
# 6        4      lion king       7
# 7        3  inter stellar       8
# 8        7       bahubali       9

# %%
#pivot the table
pivot_table=df.pivot(index='user id',columns='movie',values='rating')
print(pivot_table)
# Out:
# movie    avatar  bahubali  inception  inter stellar  lion king  titantic
# user id
# 1           NaN       NaN        9.0            NaN        NaN       8.0
# 2          10.0       NaN        7.0            NaN        NaN       NaN
# 3           8.0       NaN        NaN            8.0        NaN       9.0
# 4           NaN       NaN        NaN            NaN        7.0       NaN
# 7           NaN       9.0        NaN            NaN        NaN       NaN

# %%
pivot_table.fillna(0)
# Out:
# movie    avatar  bahubali  inception  inter stellar  lion king  titantic
# user id
# 1           0.0       0.0        9.0            0.0        0.0       8.0
# 2          10.0       0.0        7.0            0.0        0.0       0.0
# 3           8.0       0.0        0.0            8.0        0.0       9.0
# 4           0.0       0.0        0.0            0.0        7.0       0.0
# 7           0.0       9.0        0.0            0.0        0.0       0.0

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#    sepal.length  sepal.width  petal.length  petal.width     variety
# 0           5.1          3.5           1.4          0.2      setosa
# 1           4.9          3.0           1.4          0.2  versicolor
# 2           4.7          3.2           1.3          0.2      setosa
# 3           4.6          3.1           1.5          0.2   virgincia
# 4           5.0          3.6           1.4          0.2      setosa
# 5           5.4          3.9           1.7          0.4  versicolor
# 6           4.6          3.4           1.4          0.3   virgincia

# %%
#plot a graph blw sepal.length,petal.width
import matplotlib.pyplot as plt
plt.scatter(x=df['sepal.length'],y=df['petal.width'])
